# %% [markdown]
# <a href="https://colab.research.google.com/github/IshitaSrivastava28700/Python-Programming/blob/main/%5BISHITA_SRIVASTAVA%5D_(590028700)_(PYTHON_PROGRAMMING_ASSIGNMENT_EXPERIMENT_05)_%5BB_TECH(CSE)%5D_%5BSOCS%5D_(B79).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **[ISHITA SRIVASTAVA]**
#
# **(590028700)**
#
# **(B79)**
#
# **[B.TECH(CSE)]**
#
# **[SOCS]**
#
# **(PYTHON PROGRAMMING EXPERIMENT-05)**

# %% [markdown]
# **Experiment 5: Lists, tuples, dictionary**

# %% [markdown]
# **1.** **Scan n values in range 0-3 and print the number of times each value has occurred.**

# %%
# Program to count occurrences of numbers in range 0-3

# Example input list (you can replace this with user input)
values = [0, 1, 2, 3, 2, 1, 0, 3, 3, 2, 0]

# Initialize a dictionary to store counts for each number
count = {0: 0, 1: 0, 2: 0, 3: 0}

# Loop through each value in the list
for n in values:
    # Check if the number is within the range 0–3
    if 0 <= n <= 3:
        # Increase the count for that number
        count[n] += 1

# Print the results
for key in count:
    print(f"Value {key} occurred {count[key]} times")
# Out:
# Value 0 occurred 3 times
# Value 1 occurred 2 times
# Value 2 occurred 3 times
# Value 3 occurred 3 times

# %% [markdown]
# **2.**  **Create a tuple to store n numeric values and find average of all values.**

# %%
# Program to store numeric values in a tuple and find their average

# Step 1: Create a tuple with numeric values
numbers = (10, 20, 30, 40, 50)

# Step 2: Find the sum of all values in the tuple
total = sum(numbers)

# Step 3: Find the number of elements in the tuple
count = len(numbers)

# Step 4: Calculate the average
average = total / count

# Step 5: Print the result
print("The numbers are:", numbers)
print("The average of all values is:", average)
# Out:
# The numbers are: (10, 20, 30, 40, 50)
# The average of all values is: 30.0

# %% [markdown]
# **3.** **WAP to input a list of scores for N students in a list data type. Find the score of the runner
# up and print the output.**
#
# **Sample Input**
#
# **N = 5**
#
# **Scores= 2 3 6 6 5**
#
# **Sample output**
#
# **5**
#
# **Note: Given list is [2, 3, 6, 6, 5]. The maximum score is 6, second maximum is 5. Hence,
# we print 5 as the runner-up score.**

# %%
# Program to find the runner-up score from a list of student scores

# Step 1: Input number of students
N = int(input("Enter number of students: "))

# Step 2: Input scores as a list
# Using list comprehension to read N integers from user
scores = [int(x) for x in input("Enter the scores separated by space: ").split()]

# Step 3: Convert list to a set to remove duplicates
unique_scores = set(scores)

# Step 4: Remove the maximum score (the winner)
unique_scores.remove(max(unique_scores))

# Step 5: Find the new maximum (runner-up score)
runner_up = max(unique_scores)

# Step 6: Print the runner-up score
print("Runner-up score is:", runner_up)
# Out:
# Enter number of students: 5
# Enter the scores separated by space: 2 3 6 6 5
# Runner-up score is: 5

# %% [markdown]
# **4.** **Create a dictionary of n persons where key is name and value is city.**
#
# **a) Display all names**
#
# **b) Display all city names**
#
# **c) Display student name and city of all students.**
#
# **d) Count number of students in each city.**

# %%
# Program to create a dictionary of persons with name as key and city as value

# Step 1: Input number of persons
n = int(input("Enter number of persons: "))

# Step 2: Create dictionary by taking input
persons = {}
for i in range(n):
    name = input(f"Enter name of person {i+1}: ")
    city = input(f"Enter city of {name}: ")
    persons[name] = city

# a) Display all names
print("\nAll names:")
for name in persons.keys():
    print(name)

# b) Display all city names
print("\nAll cities:")
for city in persons.values():
    print(city)

# c) Display student name and city of all students
print("\nName and City of all students:")
for name, city in persons.items():
    print(f"{name} -> {city}")

# d) Count number of students in each city
print("\nNumber of students in each city:")
city_count = {}
for city in persons.values():
    city_count[city] = city_count.get(city, 0) + 1

for city, count in city_count.items():
    print(f"{city}: {count}")
# Out:
# Enter number of persons: 4
# Enter name of person 1: Aman
# Enter city of Aman: Bhopal
# Enter name of person 2: Priya
# Enter city of Priya : Jaipur
# Enter name of person 3: Kavita
# Enter city of Kavita: Bhopal
# Enter name of person 4: Snehal
# Enter city of Snehal: Jaipur
#
# All names:
# Aman
# Priya
# Kavita
# Snehal
#
# All cities:
# Bhopal
# Jaipur
# Bhopal
# Jaipur
#
# Name and City of all students:
# Aman -> Bhopal
# Priya  -> Jaipur
# Kavita -> Bhopal
# Snehal -> Jaipur
#
# Number of students in each city:
# Bhopal: 2
# Jaipur: 2

# %% [markdown]
# **5.** **Store details of n movies in a dictionary by taking input from the user. Each movie must
# store details like name,  year, director name, production cost, collection made (earning)
# & perform the following :-**
#
# **a) print all movie details**
#
# **b) display name of movies released before 2015**
#
# **c) print movies that made a profit.**
#
# **d) print movies directed by a particular director.**

# %%
# Program to store details of movies in a dictionary

# Step 1: Input number of movies
n = int(input("Enter number of movies: "))

# Step 2: Create dictionary with movie details
movies = {}
for i in range(n):
    name = input(f"\nEnter name of movie {i+1}: ")
    year = int(input("Enter release year: "))
    director = input("Enter director name: ")
    cost = float(input("Enter production cost: "))
    earning = float(input("Enter collection made (earning): "))

    # Store details as another dictionary
    movies[name] = {
        "Year": year,
        "Director": director,
        "Cost": cost,
        "Earning": earning
    }

# a) Print all movie details
print("\nAll Movie Details:")
for name, details in movies.items():
    print(f"{name} -> Year: {details['Year']}, Director: {details['Director']}, "
          f"Cost: {details['Cost']}, Earning: {details['Earning']}")

# b) Display name of movies released before 2015
print("\nMovies released before 2015:")
for name, details in movies.items():
    if details["Year"] < 2015:
        print(name)

# c) Print movies that made a profit (earning > cost)
print("\nMovies that made a profit:")
for name, details in movies.items():
    if details["Earning"] > details["Cost"]:
        print(name)

# d) Print movies directed by a particular director
director_name = input("\nEnter director name to search: ")
print(f"\nMovies directed by {director_name}:")
for name, details in movies.items():
    if details["Director"].lower() == director_name.lower():
        print(name)
# Out:
# Enter number of movies: 2
#
# Enter name of movie 1: Inception
# Enter release year: 2010
# Enter director name: Christopher Nolan
# Enter production cost: 160
# Enter collection made (earning): 829
#
# Enter name of movie 2: Tenet
# Enter release year: 2020
# Enter director name: Christopher Nolan
# Enter production cost: 200
# Enter collection made (earning): 365
#
# All Movie Details:
# Inception -> Year: 2010, Director: Christopher Nolan, Cost: 160.0, Earning: 829.0
# Tenet -> Year: 2020, Director: Christopher Nolan, Cost: 200.0, Earning: 365.0
#
# Movies released before 2015:
# Inception
#
# Movies that made a profit:
# Inception
# Tenet
#
# Enter director name to search: Christopher Nolan
#
# Movies directed by Christopher Nolan:
# Inception
# Tenet

# %% [markdown]
# **6.** **Create a contact book where users can store, search, update, and delete contacts. Use
# dictionary for storing contacts.**

# %%
# Contact Book using dictionary

contacts = {}  # Dictionary to store contacts

def add_contact():
    name = input("Enter contact name: ")
    phone = input("Enter phone number: ")
    contacts[name] = phone
    print("Contact added successfully!")

def search_contact():
    name = input("Enter name to search: ")
    if name in contacts:
        print(f"{name} -> {contacts[name]}")
    else:
        print("Contact not found.")

def update_contact():
    name = input("Enter name to update: ")
    if name in contacts:
        phone = input("Enter new phone number: ")
        contacts[name] = phone
        print("Contact updated successfully!")
    else:
        print("Contact not found.")

def delete_contact():
    name = input("Enter name to delete: ")
    if name in contacts:
        del contacts[name]
        print("Contact deleted successfully!")
    else:
        print("Contact not found.")

def display_contacts():
    print("\nAll Contacts:")
    for name, phone in contacts.items():
        print(name, "->", phone)

# Menu-driven program
while True:
    print("\n--- Contact Book Menu ---")
    print("1. Add Contact")
    print("2. Search Contact")
    print("3. Update Contact")
    print("4. Delete Contact")
    print("5. Display All Contacts")
    print("6. Exit")

    choice = input("Enter your choice (1-6): ")

    if choice == "1":
        add_contact()
    elif choice == "2":
        search_contact()
    elif choice == "3":
        update_contact()
    elif choice == "4":
        delete_contact()
    elif choice == "5":
        display_contacts()
    elif choice == "6":
        print("Exiting Contact Book. Goodbye!")
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# --- Contact Book Menu ---
# 1. Add Contact
# 2. Search Contact
# 3. Update Contact
# 4. Delete Contact
# 5. Display All Contacts
# 6. Exit
# Enter your choice (1-6): 1
# Enter contact name: Ananya
# Enter phone number: 9876501234
# Contact added successfully!
#
# --- Contact Book Menu ---
# 1. Add Contact
# 2. Search Contact
# 3. Update Contact
# 4. Delete Contact
# 5. Display All Contacts
# 6. Exit
# Enter your choice (1-6): 1
# Enter contact name: Rohan
# Enter phone number: 9123456789
# Contact added successfully!
#
# --- Contact Book Menu ---
# 1. Add Contact
# 2. Search Contact
# 3. Update Contact
# 4. Delete Contact
# 5. Display All Contacts
# 6. Exit
# Enter your choice (1-6): 5
#
# All Contacts:
# Ananya -> 9876501234
# Rohan -> 9123456789
#
# --- Contact Book Menu ---
# 1. Add Contact
# 2. Search Contact
# 3. Update Contact
# 4. Delete Contact
# 5. Display All Contacts
# 6. Exit
# Enter your choice (1-6): 2
# Enter name to search: Rohan
# Rohan -> 9123456789
#
# ...

# %% [markdown]
# **7.** **Create a Todo list Manager where users can add, view, and remove tasks. Use List for
# storing tasks.**

# %%
# Todo List Manager using List

def show_menu():
    print("\n--- Todo List Manager ---")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Remove Task")
    print("4. Exit")

def add_task(tasks):
    task = input("Enter task: ")
    tasks.append(task)
    print(f"Task '{task}' added successfully!")

def view_tasks(tasks):
    if not tasks:
        print("No tasks in the list.")
    else:
        print("\nYour Tasks:")
        for i, task in enumerate(tasks, start=1):
            print(f"{i}. {task}")

def remove_task(tasks):
    view_tasks(tasks)
    if tasks:
        try:
            index = int(input("Enter task number to remove: "))
            if 1 <= index <= len(tasks):
                removed = tasks.pop(index - 1)
                print(f"Task '{removed}' removed successfully!")
            else:
                print("Invalid task number.")
        except ValueError:
            print("Please enter a valid number.")

def main():
    tasks = []
    while True:
        show_menu()
        choice = input("Enter your choice: ")

        if choice == "1":
            add_task(tasks)
        elif choice == "2":
            view_tasks(tasks)
        elif choice == "3":
            remove_task(tasks)
        elif choice == "4":
            print("Exiting Todo List Manager. Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.")

# Run the program
if __name__ == "__main__":
    main()
# Out:
# --- Todo List Manager ---
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice: 4
# Exiting Todo List Manager. Goodbye!
